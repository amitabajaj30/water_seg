# %%
import glob
import json
import os

import cv2

#from src.create_annotations import (create_image_annotation, create_annotation_format, find_contours,
                                    #get_coco_json_format, create_category_annotation)

# Label ids of the dataset
category_ids = {"water": 1}

MASK_EXT = 'png'
ORIGINAL_EXT = 'png'

# %%
import cv2

image_id = 0


def find_contours(sub_mask):
    gray = cv2.cvtColor(sub_mask, cv2.COLOR_BGR2GRAY)
    _, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    return cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)[0]


def create_category_annotation(category_dict):
    category_list = []
    for key, value in category_dict.items():
        category = {"id": value, "name": key, "supercategory": key}
        category_list.append(category)
    return category_list


def create_image_annotation(file_name, width, height):
    global image_id
    image_id += 1
    return {
        "id": image_id,
        "width": width,
        "height": height,
        "file_name": file_name,
    }


def create_annotation_format(contour, image_id_, category_id, annotation_id):
    return {
        "iscrowd": 0,
        "id": annotation_id,
        "image_id": image_id_,
        "category_id": category_id,
        "bbox": cv2.boundingRect(contour),
        "area": cv2.contourArea(contour),
        "segmentation": [contour.flatten().tolist()],
    }


def get_coco_json_format():
    return {
        "info": {},
        "licenses": [],
        "images": [{}],
        "categories": [{}],
        "annotations": [{}],
    }

# %%
# Get "images" and "annotations" info
def images_annotations_info(maskpath):
    annotation_id = 0
    annotations = []
    images = []

    for category in category_ids.keys():
        for mask_image in glob.glob(os.path.join(maskpath, category, f'*.{MASK_EXT}')):
            original_file_name = f'{os.path.basename(mask_image).split(".")[0]}.{ORIGINAL_EXT}'
            mask_image_open = cv2.imread(mask_image)
            height, width, c = mask_image_open.shape
            print(mask_image)

            if original_file_name not in map(lambda img: img['file_name'], images):
                image = create_image_annotation(file_name=original_file_name, width=width, height=height)
                images.append(image)
            else:
                image = [element for element in images if element['file_name'] == original_file_name][0]

            contours = find_contours(mask_image_open)

            for contour in contours:
                annotation = create_annotation_format(contour, image['id'], category_ids[category], annotation_id)
                if annotation['area'] > 0:
                    annotations.append(annotation)
                    annotation_id += 1

    return images, annotations, annotation_id

# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\amita.bajaj\\Desktop\\water_semantic_segmenation'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'archive',
#  'aumented data',
#  'dataset',
#  'dataset links.txt',
#  'final_mask to json.ipynb',
#  'flood classification(Tanmay)',
#  'frames to video converter.ipynb',
#  'framestovideo',
#  'new 5.txt',
#  'new_data_aug',
#  'original',
#  'Renaming files and copying from subfolder to parent.ipynb',
#  'resized_dataset_for_json_256x256',
#  'resizing images .ipynb',
#  'selecting random data.txt',
#  'semantic_segmentation_final']

# %%
if __name__ == "__main__":
    coco_format = get_coco_json_format()  # Get the standard COCO JSON format
    
    for keyword in ["valid", "train"]:
        mask_path = f"dataset/{keyword}_mask/"
        print(mask_path)
 
        print("mask path",mask_path)
        # Create category section
        coco_format["categories"] = create_category_annotation(category_ids)

        # Create images and annotations sections
        coco_format["images"], coco_format["annotations"], annotation_cnt = images_annotations_info(mask_path)

        with open(f"dataset/{keyword}.json", "w") as outfile:
            json.dump(coco_format, outfile, sort_keys=True, indent=4)

        print("Created %d annotations for images in folder: %s" % (annotation_cnt, mask_path))
# Out:
# dataset/valid_mask/
# mask path dataset/valid_mask/
# dataset/valid_mask/water\1005-water.png
# dataset/valid_mask/water\1017-water.png
# dataset/valid_mask/water\1025-water.png
# dataset/valid_mask/water\1053-water.png
# dataset/valid_mask/water\1062-water.png
# dataset/valid_mask/water\1067-water.png
# dataset/valid_mask/water\1071-water.png
# dataset/valid_mask/water\110-water.png
# dataset/valid_mask/water\1115-water.png
# dataset/valid_mask/water\112-water.png
# dataset/valid_mask/water\1132-water.png
# dataset/valid_mask/water\1134-water.png
# dataset/valid_mask/water\1149-water.png
# dataset/valid_mask/water\1153-water.png
# dataset/valid_mask/water\1158-water.png
# dataset/valid_mask/water\1159-water.png
# dataset/valid_mask/water\1162-water.png
# dataset/valid_mask/water\1171-water.png
# dataset/valid_mask/water\1174-water.png
# dataset/valid_mask/water\1175-water.png
# dataset/valid_mask/water\1184-water.png
# dataset/valid_mask/water\1186-water.png
# dataset/valid_mask/water\1190-water.png
# dataset/valid_mask/water\1205-water.png
# dataset/valid_mask/water\1212-water.png
# dataset/valid_mask/water\1218-water.png
# dataset/valid_mask/water\1222-water.png
# dataset/valid_mask/water\1225-water.png
# dataset/valid_mask/water\1226-water.png
# dataset/valid_mask/water\1231-water.png
# dataset/valid_mask/water\1233-water.png
# dataset/valid_mask/water\1245-water.png
# dataset/valid_mask/water\1251-water.png
# dataset/valid_mask/water\1253-water.png
# dataset/valid_mask/water\1275-water.png
# dataset/valid_mask/water\1281-water.png
# dataset/valid_mask/water\1283-water.png
# dataset/valid_mask/water\1294-water.png
# dataset/valid_mask/water\1304-water.png
# dataset/valid_mask/water\1310-water.png
# dataset/valid_mask/water\1319-water.png
# dataset/valid_mask/water\1321-water.png
# dataset/valid_mask/water\1324-water.png
# dataset/valid_mask/water\1326-water.png
# dataset/valid_mask/water\1330-water.png
# dataset/valid_mask/water\1340-water.png
# dataset/valid_mask/water\1343-water.png
# dataset/valid_mask/water\1349-water.png
# dataset/valid_mask/water\1350-water.png
# dataset/valid_mask/water\1353-water.png
# dataset/valid_mask/water\1359-water.png
# dataset/valid_mask/water\1364-water.png
# dataset/valid_mask/water\1374-water.png
# dataset/valid_mask/water\1385-water.png
# dataset/valid_mask/water\1399-water.png
# dataset/valid_mask/water\1415-water.png
# dataset/valid_mask/water\1420-water.png
# dataset/valid_mask/water\1423-water.png
# dataset/valid_mask/water\1425-water.png
# dataset/valid_mask/water\1434-water.png
# dataset/valid_mask/water\1438-water.png
# dataset/valid_mask/water\1443-water.png
# dataset/valid_mask/water\1445-water.png
# dataset/valid_mask/water\1448-water.png
# dataset/valid_mask/water\1450-water.png
# dataset/valid_mask/water\1455-water.png
# dataset/valid_mask/water\1461-water.png
# dataset/valid_mask/water\1471-water.png
# dataset/valid_mask/water\1472-water.png
# dataset/valid_mask/water\1476-water.png
# dataset/valid_mask/water\1477-water.png
# dataset/valid_mask/water\1478-water.png
# dataset/valid_mask/water\1489-water.png
# dataset/valid_mask/water\1491-water.png
# dataset/valid_mask/water\1502-water.png
# dataset/valid_mask/water\1507-water.png
# dataset/valid_mask/water\1510-water.png
# dataset/valid_mask/water\1516-water.png
# dataset/valid_mask/water\1518-water.png
# dataset/valid_mask/water\1522-water.png
# dataset/valid_mask/water\1524-water.png
# dataset/valid_mask/water\1529-water.png
# dataset/valid_mask/water\1534-water.png
# dataset/valid_mask/water\1537-water.png
# dataset/valid_mask/water\1540-water.png
# dataset/valid_mask/water\1545-water.png
# dataset/valid_mask/water\1547-water.png
# dataset/valid_mask/water\1563-water.png
# dataset/valid_mask/water\1582-water.png
# dataset/valid_mask/water\1590-water.png
# dataset/valid_mask/water\1594-water.png
# dataset/valid_mask/water\1595-water.png
# dataset/valid_mask/water\1596-water.png
# dataset/valid_mask/water\1599-water.png
# dataset/valid_mask/water\1604-water.png
# dataset/valid_mask/water\1610-water.png
# dataset/valid_mask/water\1611-water.png
# dataset/valid_mask/water\1614-water.png
# dataset/valid_mask/water\1620-water.png
# dataset/valid_mask/water\1622-water.png
# dataset/valid_mask/water\1630-water.png
# dataset/valid_mask/water\1633-water.png
# dataset/valid_mask/water\1644-water.png
# dataset/valid_mask/water\1645-water.png
# dataset/valid_mask/water\1660-water.png
# dataset/valid_mask/water\1662-water.png
# dataset/valid_mask/water\1666-water.png
# dataset/valid_mask/water\1669-water.png
# dataset/valid_mask/water\1671-water.png
# dataset/valid_mask/water\1674-water.png
# dataset/valid_mask/water\1675-water.png
# dataset/valid_mask/water\168-water.png
# dataset/valid_mask/water\1686-water.png
# dataset/valid_mask/water\1690-water.png
# dataset/valid_mask/water\1697-water.png
# dataset/valid_mask/water\1702-water.png
# dataset/valid_mask/water\1708-water.png
# dataset/valid_mask/water\1710-water.png
# dataset/valid_mask/water\1712-water.png
# dataset/valid_mask/water\1713-water.png
# dataset/valid_mask/water\1714-water.png
# dataset/valid_mask/water\1727-water.png
# dataset/valid_mask/water\1738-water.png
# dataset/valid_mask/water\1740-water.png
# dataset/valid_mask/water\1741-water.png
# dataset/valid_mask/water\1748-water.png
# dataset/valid_mask/water\1749-water.png
# dataset/valid_mask/water\1785-water.png
# dataset/valid_mask/water\1806-water.png
# dataset/valid_mask/water\1848-water.png
# dataset/valid_mask/water\1882-water.png
# dataset/valid_mask/water\190-water.png
# dataset/valid_mask/water\1908-water.png
# dataset/valid_mask/water\1918-water.png
# dataset/valid_mask/water\1926-water.png
# dataset/valid_mask/water\1958-water.png
# dataset/valid_mask/water\1960-water.png
# dataset/valid_mask/water\1963-water.png
# dataset/valid_mask/water\197-water.png
# dataset/valid_mask/water\1974-water.png
# dataset/valid_mask/water\2000-water.png
# dataset/valid_mask/water\2050-water.png
# dataset/valid_mask/water\2136-water.png
# dataset/valid_mask/water\2139-water.png
# dataset/valid_mask/water\2147-water.png
# dataset/valid_mask/water\2155-water.png
# dataset/valid_mask/water\2158-water.png
# dataset/valid_mask/water\2167-water.png
# dataset/valid_mask/water\2187-water.png
# dataset/valid_mask/water\2206-water.png
# dataset/valid_mask/water\2215-water.png
# dataset/valid_mask/water\2240-water.png
# dataset/valid_mask/water\2245-water.png
# dataset/valid_mask/water\2248-water.png
# dataset/valid_mask/water\2279-water.png
# dataset/valid_mask/water\2294-water.png
# dataset/valid_mask/water\2295-water.png
# dataset/valid_mask/water\2296-water.png
# dataset/valid_mask/water\2299-water.png
# dataset/valid_mask/water\2302-water.png
# dataset/valid_mask/water\231-water.png
# dataset/valid_mask/water\2324-water.png
# dataset/valid_mask/water\2335-water.png
# dataset/valid_mask/water\2354-water.png
# dataset/valid_mask/water\2374-water.png
# dataset/valid_mask/water\2375-water.png
# dataset/valid_mask/water\240-water.png
# dataset/valid_mask/water\2402-water.png
# dataset/valid_mask/water\2406-water.png
# dataset/valid_mask/water\2433-water.png
# dataset/valid_mask/water\2454-water.png
# dataset/valid_mask/water\2455-water.png
# dataset/valid_mask/water\2468-water.png
# dataset/valid_mask/water\2476-water.png
# dataset/valid_mask/water\248-water.png
# dataset/valid_mask/water\2495-water.png
# dataset/valid_mask/water\2508-water.png
# dataset/valid_mask/water\2510-water.png
# dataset/valid_mask/water\2516-water.png
# dataset/valid_mask/water\252-water.png
# dataset/valid_mask/water\2520-water.png
# dataset/valid_mask/water\253-water.png
# dataset/valid_mask/water\2535-water.png
# dataset/valid_mask/water\2556-water.png
# dataset/valid_mask/water\2585-water.png
# dataset/valid_mask/water\2596-water.png
# dataset/valid_mask/water\266-water.png
# dataset/valid_mask/water\27-water.png
# dataset/valid_mask/water\278-water.png
# dataset/valid_mask/water\302-water.png
# dataset/valid_mask/water\305-water.png
# dataset/valid_mask/water\316-water.png
# dataset/valid_mask/water\328-water.png
# dataset/valid_mask/water\342-water.png
# dataset/valid_mask/water\343-water.png
# dataset/valid_mask/water\356-water.png
# dataset/valid_mask/water\367-water.png
# dataset/valid_mask/water\379-water.png
# dataset/valid_mask/water\399-water.png
# dataset/valid_mask/water\412-water.png
# dataset/valid_mask/water\414-water.png
# dataset/valid_mask/water\42-water.png
# dataset/valid_mask/water\429-water.png
# dataset/valid_mask/water\462-water.png
# dataset/valid_mask/water\471-water.png
# dataset/valid_mask/water\496-water.png
# dataset/valid_mask/water\527-water.png
# dataset/valid_mask/water\529-water.png
# dataset/valid_mask/water\574-water.png
# dataset/valid_mask/water\587-water.png
# dataset/valid_mask/water\599-water.png
# dataset/valid_mask/water\6-water.png
# dataset/valid_mask/water\606-water.png
# dataset/valid_mask/water\615-water.png
# dataset/valid_mask/water\632-water.png
# dataset/valid_mask/water\633-water.png
# dataset/valid_mask/water\637-water.png
# dataset/valid_mask/water\697-water.png
# dataset/valid_mask/water\70-water.png
# dataset/valid_mask/water\712-water.png
# dataset/valid_mask/water\741-water.png
# dataset/valid_mask/water\748-water.png
# dataset/valid_mask/water\757-water.png
# dataset/valid_mask/water\763-water.png
# dataset/valid_mask/water\779-water.png
# dataset/valid_mask/water\793-water.png
# dataset/valid_mask/water\806-water.png
# dataset/valid_mask/water\813-water.png
# dataset/valid_mask/water\817-water.png
# dataset/valid_mask/water\856-water.png
# dataset/valid_mask/water\862-water.png
# dataset/valid_mask/water\890-water.png
# dataset/valid_mask/water\921-water.png
# dataset/valid_mask/water\925-water.png
# dataset/valid_mask/water\954-water.png
# dataset/valid_mask/water\976-water.png
# dataset/valid_mask/water\99-water.png
# Created 670 annotations for images in folder: dataset/valid_mask/
# dataset/train_mask/
# mask path dataset/train_mask/
# dataset/train_mask/water\1-water.png
# dataset/train_mask/water\10-water.png
# dataset/train_mask/water\100-water.png
# dataset/train_mask/water\1000-water.png
# dataset/train_mask/water\1001-water.png
# dataset/train_mask/water\1002-water.png
# dataset/train_mask/water\1003-water.png
# dataset/train_mask/water\1004-water.png
# dataset/train_mask/water\1006-water.png
# dataset/train_mask/water\1007-water.png
# dataset/train_mask/water\1008-water.png
# dataset/train_mask/water\101-water.png
# dataset/train_mask/water\1010-water.png
# dataset/train_mask/water\1011-water.png
# dataset/train_mask/water\1012-water.png
# dataset/train_mask/water\1013-water.png
# dataset/train_mask/water\1015-water.png
# dataset/train_mask/water\1016-water.png
# dataset/train_mask/water\1018-water.png
# dataset/train_mask/water\1020-water.png
# dataset/train_mask/water\1021-water.png
# dataset/train_mask/water\1022-water.png
# dataset/train_mask/water\1024-water.png
# dataset/train_mask/water\1026-water.png
# dataset/train_mask/water\1027-water.png
# dataset/train_mask/water\1028-water.png
# dataset/train_mask/water\1029-water.png
# dataset/train_mask/water\103-water.png
# dataset/train_mask/water\1030-water.png
# dataset/train_mask/water\1031-water.png
# dataset/train_mask/water\1032-water.png
# dataset/train_mask/water\1033-water.png
# dataset/train_mask/water\1034-water.png
# dataset/train_mask/water\1035-water.png
# dataset/train_mask/water\1036-water.png
# dataset/train_mask/water\1037-water.png
# dataset/train_mask/water\1038-water.png
# dataset/train_mask/water\1039-water.png
# dataset/train_mask/water\104-water.png
# dataset/train_mask/water\1040-water.png
# dataset/train_mask/water\1042-water.png
# dataset/train_mask/water\1044-water.png
# dataset/train_mask/water\1045-water.png
# dataset/train_mask/water\1046-water.png
# dataset/train_mask/water\1047-water.png
# dataset/train_mask/water\1048-water.png
# dataset/train_mask/water\1049-water.png
# dataset/train_mask/water\105-water.png
# dataset/train_mask/water\1050-water.png
# dataset/train_mask/water\1051-water.png
# dataset/train_mask/water\1052-water.png
# dataset/train_mask/water\1054-water.png
# dataset/train_mask/water\1055-water.png
# dataset/train_mask/water\1056-water.png
# dataset/train_mask/water\1057-water.png
# dataset/train_mask/water\1058-water.png
# dataset/train_mask/water\1059-water.png
# dataset/train_mask/water\106-water.png
# dataset/train_mask/water\1060-water.png
# dataset/train_mask/water\1061-water.png
# dataset/train_mask/water\1064-water.png
# dataset/train_mask/water\1065-water.png
# dataset/train_mask/water\1066-water.png
# dataset/train_mask/water\1069-water.png
# dataset/train_mask/water\107-water.png
# dataset/train_mask/water\1070-water.png
# dataset/train_mask/water\1072-water.png
# dataset/train_mask/water\1073-water.png
# dataset/train_mask/water\1074-water.png
# dataset/train_mask/water\1076-water.png
# dataset/train_mask/water\1077-water.png
# dataset/train_mask/water\1078-water.png
# dataset/train_mask/water\1079-water.png
# dataset/train_mask/water\108-water.png
# dataset/train_mask/water\1080-water.png
# dataset/train_mask/water\1081-water.png
# dataset/train_mask/water\1082-water.png
# dataset/train_mask/water\1083-water.png
# dataset/train_mask/water\1084-water.png
# dataset/train_mask/water\1085-water.png
# dataset/train_mask/water\1086-water.png
# dataset/train_mask/water\1087-water.png
# dataset/train_mask/water\1088-water.png
# dataset/train_mask/water\1089-water.png
# dataset/train_mask/water\1090-water.png
# dataset/train_mask/water\1091-water.png
# dataset/train_mask/water\1092-water.png
# dataset/train_mask/water\1093-water.png
# dataset/train_mask/water\1094-water.png
# dataset/train_mask/water\1095-water.png
# dataset/train_mask/water\1096-water.png
# dataset/train_mask/water\1097-water.png
# dataset/train_mask/water\1098-water.png
# dataset/train_mask/water\1099-water.png
# dataset/train_mask/water\11-water.png
# dataset/train_mask/water\1100-water.png
# dataset/train_mask/water\1101-water.png
# dataset/train_mask/water\1102-water.png
# dataset/train_mask/water\1103-water.png
# dataset/train_mask/water\1104-water.png
# dataset/train_mask/water\1105-water.png
# dataset/train_mask/water\1106-water.png
# dataset/train_mask/water\1107-water.png
# dataset/train_mask/water\1108-water.png
# dataset/train_mask/water\1109-water.png
# dataset/train_mask/water\111-water.png
# dataset/train_mask/water\1110-water.png
# dataset/train_mask/water\1111-water.png
# dataset/train_mask/water\1112-water.png
# dataset/train_mask/water\1113-water.png
# dataset/train_mask/water\1114-water.png
# dataset/train_mask/water\1116-water.png
# dataset/train_mask/water\1117-water.png
# dataset/train_mask/water\1118-water.png
# dataset/train_mask/water\1119-water.png
# dataset/train_mask/water\1120-water.png
# dataset/train_mask/water\1121-water.png
# dataset/train_mask/water\1122-water.png
# dataset/train_mask/water\1123-water.png
# dataset/train_mask/water\1124-water.png
# dataset/train_mask/water\1127-water.png
# dataset/train_mask/water\1128-water.png
# dataset/train_mask/water\1129-water.png
# dataset/train_mask/water\113-water.png
# dataset/train_mask/water\1130-water.png
# dataset/train_mask/water\1131-water.png
# dataset/train_mask/water\1133-water.png
# dataset/train_mask/water\1135-water.png
# dataset/train_mask/water\1136-water.png
# dataset/train_mask/water\1137-water.png
# dataset/train_mask/water\1138-water.png
# dataset/train_mask/water\1139-water.png
# dataset/train_mask/water\1140-water.png
# dataset/train_mask/water\1141-water.png
# dataset/train_mask/water\1142-water.png
# dataset/train_mask/water\1143-water.png
# dataset/train_mask/water\1144-water.png
# dataset/train_mask/water\1145-water.png
# dataset/train_mask/water\1146-water.png
# dataset/train_mask/water\1147-water.png
# dataset/train_mask/water\1148-water.png
# dataset/train_mask/water\115-water.png
# dataset/train_mask/water\1150-water.png
# dataset/train_mask/water\1151-water.png
# dataset/train_mask/water\1152-water.png
# dataset/train_mask/water\1154-water.png
# dataset/train_mask/water\1155-water.png
# dataset/train_mask/water\1156-water.png
# dataset/train_mask/water\1157-water.png
# dataset/train_mask/water\1160-water.png
# dataset/train_mask/water\1161-water.png
# dataset/train_mask/water\1163-water.png
# dataset/train_mask/water\1164-water.png
# dataset/train_mask/water\1165-water.png
# dataset/train_mask/water\1166-water.png
# dataset/train_mask/water\1167-water.png
# dataset/train_mask/water\1168-water.png
# dataset/train_mask/water\1169-water.png
# dataset/train_mask/water\117-water.png
# dataset/train_mask/water\1170-water.png
# dataset/train_mask/water\1172-water.png
# dataset/train_mask/water\1173-water.png
# dataset/train_mask/water\1176-water.png
# dataset/train_mask/water\1177-water.png
# dataset/train_mask/water\1178-water.png
# dataset/train_mask/water\1179-water.png
# dataset/train_mask/water\1180-water.png
# dataset/train_mask/water\1181-water.png
# dataset/train_mask/water\1182-water.png
# dataset/train_mask/water\1183-water.png
# dataset/train_mask/water\1185-water.png
# dataset/train_mask/water\1187-water.png
# dataset/train_mask/water\1188-water.png
# dataset/train_mask/water\1189-water.png
# dataset/train_mask/water\119-water.png
# dataset/train_mask/water\1191-water.png
# dataset/train_mask/water\1192-water.png
# dataset/train_mask/water\1193-water.png
# dataset/train_mask/water\1194-water.png
# dataset/train_mask/water\1195-water.png
# dataset/train_mask/water\1196-water.png
# dataset/train_mask/water\1197-water.png
# dataset/train_mask/water\1198-water.png
# dataset/train_mask/water\1199-water.png
# dataset/train_mask/water\12-water.png
# dataset/train_mask/water\120-water.png
# dataset/train_mask/water\1200-water.png
# dataset/train_mask/water\1201-water.png
# dataset/train_mask/water\1202-water.png
# dataset/train_mask/water\1203-water.png
# dataset/train_mask/water\1204-water.png
# dataset/train_mask/water\1206-water.png
# dataset/train_mask/water\1207-water.png
# dataset/train_mask/water\1208-water.png
# dataset/train_mask/water\1209-water.png
# dataset/train_mask/water\121-water.png
# dataset/train_mask/water\1210-water.png
# dataset/train_mask/water\1211-water.png
# dataset/train_mask/water\1213-water.png
# dataset/train_mask/water\1214-water.png
# dataset/train_mask/water\1215-water.png
# dataset/train_mask/water\1216-water.png
# dataset/train_mask/water\1217-water.png
# dataset/train_mask/water\1219-water.png
# dataset/train_mask/water\122-water.png
# dataset/train_mask/water\1220-water.png
# dataset/train_mask/water\1221-water.png
# dataset/train_mask/water\1223-water.png
# dataset/train_mask/water\1224-water.png
# dataset/train_mask/water\1227-water.png
# dataset/train_mask/water\1228-water.png
# dataset/train_mask/water\1229-water.png
# dataset/train_mask/water\123-water.png
# dataset/train_mask/water\1230-water.png
# dataset/train_mask/water\1232-water.png
# dataset/train_mask/water\1234-water.png
# dataset/train_mask/water\1235-water.png
# dataset/train_mask/water\1236-water.png
# dataset/train_mask/water\1237-water.png
# dataset/train_mask/water\1238-water.png
# dataset/train_mask/water\1239-water.png
# dataset/train_mask/water\1240-water.png
# dataset/train_mask/water\1241-water.png
# dataset/train_mask/water\1242-water.png
# dataset/train_mask/water\1243-water.png
# dataset/train_mask/water\1244-water.png
# dataset/train_mask/water\1246-water.png
# dataset/train_mask/water\1247-water.png
# dataset/train_mask/water\1248-water.png
# dataset/train_mask/water\1249-water.png
# dataset/train_mask/water\125-water.png
# dataset/train_mask/water\1250-water.png
# dataset/train_mask/water\1252-water.png
# dataset/train_mask/water\1254-water.png
# dataset/train_mask/water\1255-water.png
# dataset/train_mask/water\1256-water.png
# dataset/train_mask/water\1257-water.png
# dataset/train_mask/water\1258-water.png
# dataset/train_mask/water\1259-water.png
# dataset/train_mask/water\126-water.png
# dataset/train_mask/water\1260-water.png
# dataset/train_mask/water\1261-water.png
# dataset/train_mask/water\1262-water.png
# dataset/train_mask/water\1263-water.png
# dataset/train_mask/water\1264-water.png
# dataset/train_mask/water\1265-water.png
# dataset/train_mask/water\1266-water.png
# dataset/train_mask/water\1267-water.png
# dataset/train_mask/water\1268-water.png
# dataset/train_mask/water\1269-water.png
# dataset/train_mask/water\1270-water.png
# dataset/train_mask/water\1271-water.png
# dataset/train_mask/water\1272-water.png
# dataset/train_mask/water\1273-water.png
# dataset/train_mask/water\1274-water.png
# dataset/train_mask/water\1276-water.png
# dataset/train_mask/water\1277-water.png
# dataset/train_mask/water\1278-water.png
# dataset/train_mask/water\1279-water.png
# dataset/train_mask/water\1280-water.png
# dataset/train_mask/water\1282-water.png
# dataset/train_mask/water\1284-water.png
# dataset/train_mask/water\1285-water.png
# dataset/train_mask/water\1286-water.png
# dataset/train_mask/water\1287-water.png
# dataset/train_mask/water\1288-water.png
# dataset/train_mask/water\1289-water.png
# dataset/train_mask/water\129-water.png
# dataset/train_mask/water\1290-water.png
# dataset/train_mask/water\1291-water.png
# dataset/train_mask/water\1292-water.png
# dataset/train_mask/water\1293-water.png
# dataset/train_mask/water\1295-water.png
# dataset/train_mask/water\1296-water.png
# dataset/train_mask/water\1297-water.png
# dataset/train_mask/water\1298-water.png
# dataset/train_mask/water\1299-water.png
# dataset/train_mask/water\13-water.png
# dataset/train_mask/water\130-water.png
# dataset/train_mask/water\1300-water.png
# dataset/train_mask/water\1301-water.png
# dataset/train_mask/water\1302-water.png
# dataset/train_mask/water\1303-water.png
# dataset/train_mask/water\1305-water.png
# dataset/train_mask/water\1306-water.png
# dataset/train_mask/water\1307-water.png
# dataset/train_mask/water\1308-water.png
# dataset/train_mask/water\1309-water.png
# dataset/train_mask/water\1311-water.png
# dataset/train_mask/water\1312-water.png
# dataset/train_mask/water\1313-water.png
# dataset/train_mask/water\1314-water.png
# dataset/train_mask/water\1315-water.png
# dataset/train_mask/water\1316-water.png
# dataset/train_mask/water\1317-water.png
# dataset/train_mask/water\1318-water.png
# dataset/train_mask/water\132-water.png
# dataset/train_mask/water\1320-water.png
# dataset/train_mask/water\1322-water.png
# dataset/train_mask/water\1323-water.png
# dataset/train_mask/water\1325-water.png
# dataset/train_mask/water\1327-water.png
# dataset/train_mask/water\1328-water.png
# dataset/train_mask/water\1329-water.png
# dataset/train_mask/water\133-water.png
# dataset/train_mask/water\1331-water.png
# dataset/train_mask/water\1332-water.png
# dataset/train_mask/water\1333-water.png
# dataset/train_mask/water\1334-water.png
# dataset/train_mask/water\1335-water.png
# dataset/train_mask/water\1336-water.png
# dataset/train_mask/water\1337-water.png
# dataset/train_mask/water\1338-water.png
# dataset/train_mask/water\1339-water.png
# dataset/train_mask/water\1341-water.png
# dataset/train_mask/water\1342-water.png
# dataset/train_mask/water\1344-water.png
# dataset/train_mask/water\1345-water.png
# dataset/train_mask/water\1346-water.png
# dataset/train_mask/water\1347-water.png
# dataset/train_mask/water\1348-water.png
# dataset/train_mask/water\135-water.png
# dataset/train_mask/water\1351-water.png
# dataset/train_mask/water\1352-water.png
# dataset/train_mask/water\1354-water.png
# dataset/train_mask/water\1355-water.png
# dataset/train_mask/water\1356-water.png
# dataset/train_mask/water\1357-water.png
# dataset/train_mask/water\1358-water.png
# dataset/train_mask/water\1360-water.png
# dataset/train_mask/water\1361-water.png
# dataset/train_mask/water\1362-water.png
# dataset/train_mask/water\1363-water.png
# dataset/train_mask/water\1365-water.png
# dataset/train_mask/water\1366-water.png
# dataset/train_mask/water\1367-water.png
# dataset/train_mask/water\1368-water.png
# dataset/train_mask/water\1369-water.png
# dataset/train_mask/water\137-water.png
# dataset/train_mask/water\1370-water.png
# dataset/train_mask/water\1371-water.png
# dataset/train_mask/water\1372-water.png
# dataset/train_mask/water\1373-water.png
# dataset/train_mask/water\1375-water.png
# dataset/train_mask/water\1376-water.png
# dataset/train_mask/water\1377-water.png
# dataset/train_mask/water\1378-water.png
# dataset/train_mask/water\1379-water.png
# dataset/train_mask/water\138-water.png
# dataset/train_mask/water\1380-water.png
# dataset/train_mask/water\1381-water.png
# dataset/train_mask/water\1382-water.png
# dataset/train_mask/water\1383-water.png
# dataset/train_mask/water\1384-water.png
# dataset/train_mask/water\1386-water.png
# dataset/train_mask/water\1387-water.png
# dataset/train_mask/water\1388-water.png
# dataset/train_mask/water\1389-water.png
# dataset/train_mask/water\139-water.png
# dataset/train_mask/water\1390-water.png
# dataset/train_mask/water\1391-water.png
# dataset/train_mask/water\1392-water.png
# dataset/train_mask/water\1393-water.png
# dataset/train_mask/water\1394-water.png
# dataset/train_mask/water\1395-water.png
# dataset/train_mask/water\1396-water.png
# dataset/train_mask/water\1397-water.png
# dataset/train_mask/water\1398-water.png
# dataset/train_mask/water\14-water.png
# dataset/train_mask/water\140-water.png
# dataset/train_mask/water\1400-water.png
# dataset/train_mask/water\1401-water.png
# dataset/train_mask/water\1402-water.png
# dataset/train_mask/water\1403-water.png
# dataset/train_mask/water\1404-water.png
# dataset/train_mask/water\1405-water.png
# dataset/train_mask/water\1406-water.png
# dataset/train_mask/water\1407-water.png
# dataset/train_mask/water\1408-water.png
# dataset/train_mask/water\1409-water.png
# dataset/train_mask/water\141-water.png
# dataset/train_mask/water\1410-water.png
# dataset/train_mask/water\1411-water.png
# dataset/train_mask/water\1412-water.png
# dataset/train_mask/water\1413-water.png
# dataset/train_mask/water\1414-water.png
# dataset/train_mask/water\1416-water.png
# dataset/train_mask/water\1417-water.png
# dataset/train_mask/water\1418-water.png
# dataset/train_mask/water\1419-water.png
# dataset/train_mask/water\1421-water.png
# dataset/train_mask/water\1422-water.png
# dataset/train_mask/water\1424-water.png
# dataset/train_mask/water\1426-water.png
# dataset/train_mask/water\1427-water.png
# dataset/train_mask/water\1428-water.png
# dataset/train_mask/water\1429-water.png
# dataset/train_mask/water\143-water.png
# dataset/train_mask/water\1430-water.png
# dataset/train_mask/water\1431-water.png
# dataset/train_mask/water\1432-water.png
# dataset/train_mask/water\1433-water.png
# dataset/train_mask/water\1435-water.png
# dataset/train_mask/water\1436-water.png
# dataset/train_mask/water\1437-water.png
# dataset/train_mask/water\1439-water.png
# dataset/train_mask/water\1440-water.png
# dataset/train_mask/water\1441-water.png
# dataset/train_mask/water\1442-water.png
# dataset/train_mask/water\1444-water.png
# dataset/train_mask/water\1446-water.png
# dataset/train_mask/water\1447-water.png
# dataset/train_mask/water\1449-water.png
# dataset/train_mask/water\145-water.png
# dataset/train_mask/water\1451-water.png
# dataset/train_mask/water\1452-water.png
# dataset/train_mask/water\1453-water.png
# dataset/train_mask/water\1454-water.png
# dataset/train_mask/water\1456-water.png
# dataset/train_mask/water\1457-water.png
# dataset/train_mask/water\1458-water.png
# dataset/train_mask/water\1459-water.png
# dataset/train_mask/water\146-water.png
# dataset/train_mask/water\1460-water.png
# dataset/train_mask/water\1462-water.png
# dataset/train_mask/water\1463-water.png
# dataset/train_mask/water\1464-water.png
# dataset/train_mask/water\1465-water.png
# dataset/train_mask/water\1466-water.png
# dataset/train_mask/water\1467-water.png
# dataset/train_mask/water\1468-water.png
# dataset/train_mask/water\1469-water.png
# dataset/train_mask/water\147-water.png
# dataset/train_mask/water\1470-water.png
# dataset/train_mask/water\1473-water.png
# dataset/train_mask/water\1474-water.png
# dataset/train_mask/water\1475-water.png
# dataset/train_mask/water\1479-water.png
# dataset/train_mask/water\148-water.png
# dataset/train_mask/water\1480-water.png
# dataset/train_mask/water\1481-water.png
# dataset/train_mask/water\1482-water.png
# dataset/train_mask/water\1483-water.png
# dataset/train_mask/water\1484-water.png
# dataset/train_mask/water\1485-water.png
# dataset/train_mask/water\1486-water.png
# dataset/train_mask/water\1487-water.png
# dataset/train_mask/water\1488-water.png
# dataset/train_mask/water\149-water.png
# dataset/train_mask/water\1490-water.png
# dataset/train_mask/water\1492-water.png
# dataset/train_mask/water\1493-water.png
# dataset/train_mask/water\1494-water.png
# dataset/train_mask/water\1495-water.png
# dataset/train_mask/water\1496-water.png
# dataset/train_mask/water\1497-water.png
# dataset/train_mask/water\1498-water.png
# dataset/train_mask/water\1499-water.png
# dataset/train_mask/water\15-water.png
# dataset/train_mask/water\1500-water.png
# dataset/train_mask/water\1501-water.png
# dataset/train_mask/water\1503-water.png
# dataset/train_mask/water\1504-water.png
# dataset/train_mask/water\1505-water.png
# dataset/train_mask/water\1506-water.png
# dataset/train_mask/water\1508-water.png
# dataset/train_mask/water\1509-water.png
# dataset/train_mask/water\151-water.png
# dataset/train_mask/water\1511-water.png
# dataset/train_mask/water\1512-water.png
# dataset/train_mask/water\1513-water.png
# dataset/train_mask/water\1514-water.png
# dataset/train_mask/water\1515-water.png
# dataset/train_mask/water\1517-water.png
# dataset/train_mask/water\1519-water.png
# dataset/train_mask/water\152-water.png
# dataset/train_mask/water\1520-water.png
# dataset/train_mask/water\1521-water.png
# dataset/train_mask/water\1523-water.png
# dataset/train_mask/water\1525-water.png
# dataset/train_mask/water\1526-water.png
# dataset/train_mask/water\1527-water.png
# dataset/train_mask/water\1528-water.png
# dataset/train_mask/water\153-water.png
# dataset/train_mask/water\1530-water.png
# dataset/train_mask/water\1531-water.png
# dataset/train_mask/water\1532-water.png
# dataset/train_mask/water\1533-water.png
# dataset/train_mask/water\1535-water.png
# dataset/train_mask/water\1536-water.png
# dataset/train_mask/water\1538-water.png
# dataset/train_mask/water\1539-water.png
# dataset/train_mask/water\154-water.png
# dataset/train_mask/water\1541-water.png
# dataset/train_mask/water\1542-water.png
# dataset/train_mask/water\1543-water.png
# dataset/train_mask/water\1544-water.png
# dataset/train_mask/water\1546-water.png
# dataset/train_mask/water\1548-water.png
# dataset/train_mask/water\1549-water.png
# dataset/train_mask/water\155-water.png
# dataset/train_mask/water\1550-water.png
# dataset/train_mask/water\1551-water.png
# dataset/train_mask/water\1552-water.png
# dataset/train_mask/water\1553-water.png
# dataset/train_mask/water\1554-water.png
# dataset/train_mask/water\1555-water.png
# dataset/train_mask/water\1556-water.png
# dataset/train_mask/water\1557-water.png
# dataset/train_mask/water\1558-water.png
# dataset/train_mask/water\1559-water.png
# dataset/train_mask/water\1560-water.png
# dataset/train_mask/water\1561-water.png
# dataset/train_mask/water\1562-water.png
# dataset/train_mask/water\1564-water.png
# dataset/train_mask/water\1565-water.png
# dataset/train_mask/water\1566-water.png
# dataset/train_mask/water\1567-water.png
# dataset/train_mask/water\1568-water.png
# dataset/train_mask/water\1569-water.png
# dataset/train_mask/water\157-water.png
# dataset/train_mask/water\1570-water.png
# dataset/train_mask/water\1571-water.png
# dataset/train_mask/water\1572-water.png
# dataset/train_mask/water\1573-water.png
# dataset/train_mask/water\1574-water.png
# dataset/train_mask/water\1575-water.png
# dataset/train_mask/water\1576-water.png
# dataset/train_mask/water\1577-water.png
# dataset/train_mask/water\1578-water.png
# dataset/train_mask/water\1579-water.png
# dataset/train_mask/water\158-water.png
# dataset/train_mask/water\1580-water.png
# dataset/train_mask/water\1581-water.png
# dataset/train_mask/water\1583-water.png
# dataset/train_mask/water\1584-water.png
# dataset/train_mask/water\1585-water.png
# dataset/train_mask/water\1586-water.png
# dataset/train_mask/water\1587-water.png
# dataset/train_mask/water\1588-water.png
# dataset/train_mask/water\1589-water.png
# dataset/train_mask/water\159-water.png
# dataset/train_mask/water\1591-water.png
# dataset/train_mask/water\1592-water.png
# dataset/train_mask/water\1593-water.png
# dataset/train_mask/water\1597-water.png
# dataset/train_mask/water\1598-water.png
# dataset/train_mask/water\16-water.png
# dataset/train_mask/water\160-water.png
# dataset/train_mask/water\1600-water.png
# dataset/train_mask/water\1601-water.png
# dataset/train_mask/water\1602-water.png
# dataset/train_mask/water\1603-water.png
# dataset/train_mask/water\1605-water.png
# dataset/train_mask/water\1606-water.png
# dataset/train_mask/water\1607-water.png
# dataset/train_mask/water\1608-water.png
# dataset/train_mask/water\1609-water.png
# dataset/train_mask/water\161-water.png
# dataset/train_mask/water\1612-water.png
# dataset/train_mask/water\1613-water.png
# dataset/train_mask/water\1615-water.png
# dataset/train_mask/water\1616-water.png
# dataset/train_mask/water\1617-water.png
# dataset/train_mask/water\1618-water.png
# dataset/train_mask/water\1619-water.png
# dataset/train_mask/water\162-water.png
# dataset/train_mask/water\1621-water.png
# dataset/train_mask/water\1623-water.png
# dataset/train_mask/water\1624-water.png
# dataset/train_mask/water\1625-water.png
# dataset/train_mask/water\1626-water.png
# dataset/train_mask/water\1627-water.png
# dataset/train_mask/water\1628-water.png
# dataset/train_mask/water\1629-water.png
# dataset/train_mask/water\163-water.png
# dataset/train_mask/water\1631-water.png
# dataset/train_mask/water\1632-water.png
# dataset/train_mask/water\1634-water.png
# dataset/train_mask/water\1635-water.png
# dataset/train_mask/water\1636-water.png
# dataset/train_mask/water\1637-water.png
# dataset/train_mask/water\1638-water.png
# dataset/train_mask/water\1639-water.png
# dataset/train_mask/water\164-water.png
# dataset/train_mask/water\1640-water.png
# dataset/train_mask/water\1641-water.png
# dataset/train_mask/water\1642-water.png
# dataset/train_mask/water\1643-water.png
# dataset/train_mask/water\1646-water.png
# dataset/train_mask/water\1647-water.png
# dataset/train_mask/water\1648-water.png
# dataset/train_mask/water\1649-water.png
# dataset/train_mask/water\165-water.png
# dataset/train_mask/water\1650-water.png
# dataset/train_mask/water\1651-water.png
# dataset/train_mask/water\1652-water.png
# dataset/train_mask/water\1653-water.png
# dataset/train_mask/water\1654-water.png
# dataset/train_mask/water\1655-water.png
# dataset/train_mask/water\1656-water.png
# dataset/train_mask/water\1657-water.png
# dataset/train_mask/water\1658-water.png
# dataset/train_mask/water\1659-water.png
# dataset/train_mask/water\166-water.png
# dataset/train_mask/water\1661-water.png
# dataset/train_mask/water\1663-water.png
# dataset/train_mask/water\1664-water.png
# dataset/train_mask/water\1665-water.png
# dataset/train_mask/water\1667-water.png
# dataset/train_mask/water\1668-water.png
# dataset/train_mask/water\167-water.png
# dataset/train_mask/water\1670-water.png
# dataset/train_mask/water\1672-water.png
# dataset/train_mask/water\1673-water.png
# dataset/train_mask/water\1676-water.png
# dataset/train_mask/water\1677-water.png
# dataset/train_mask/water\1678-water.png
# dataset/train_mask/water\1679-water.png
# dataset/train_mask/water\1680-water.png
# dataset/train_mask/water\1681-water.png
# dataset/train_mask/water\1682-water.png
# dataset/train_mask/water\1683-water.png
# dataset/train_mask/water\1684-water.png
# dataset/train_mask/water\1685-water.png
# dataset/train_mask/water\1687-water.png
# dataset/train_mask/water\1688-water.png
# dataset/train_mask/water\1689-water.png
# dataset/train_mask/water\169-water.png
# dataset/train_mask/water\1691-water.png
# dataset/train_mask/water\1692-water.png
# dataset/train_mask/water\1693-water.png
# dataset/train_mask/water\1694-water.png
# dataset/train_mask/water\1695-water.png
# dataset/train_mask/water\1696-water.png
# dataset/train_mask/water\1698-water.png
# dataset/train_mask/water\1699-water.png
# dataset/train_mask/water\17-water.png
# dataset/train_mask/water\170-water.png
# dataset/train_mask/water\1700-water.png
# dataset/train_mask/water\1701-water.png
# dataset/train_mask/water\1703-water.png
# dataset/train_mask/water\1704-water.png
# dataset/train_mask/water\1705-water.png
# dataset/train_mask/water\1706-water.png
# dataset/train_mask/water\1707-water.png
# dataset/train_mask/water\1709-water.png
# dataset/train_mask/water\1711-water.png
# dataset/train_mask/water\1715-water.png
# dataset/train_mask/water\1716-water.png
# dataset/train_mask/water\1717-water.png
# dataset/train_mask/water\1718-water.png
# dataset/train_mask/water\1719-water.png
# dataset/train_mask/water\172-water.png
# dataset/train_mask/water\1720-water.png
# dataset/train_mask/water\1721-water.png
# dataset/train_mask/water\1722-water.png
# dataset/train_mask/water\1723-water.png
# dataset/train_mask/water\1724-water.png
# dataset/train_mask/water\1725-water.png
# dataset/train_mask/water\1726-water.png
# dataset/train_mask/water\1728-water.png
# dataset/train_mask/water\1729-water.png
# dataset/train_mask/water\173-water.png
# dataset/train_mask/water\1730-water.png
# dataset/train_mask/water\1731-water.png
# dataset/train_mask/water\1732-water.png
# dataset/train_mask/water\1733-water.png
# dataset/train_mask/water\1734-water.png
# dataset/train_mask/water\1735-water.png
# dataset/train_mask/water\1736-water.png
# dataset/train_mask/water\1737-water.png
# dataset/train_mask/water\1739-water.png
# dataset/train_mask/water\174-water.png
# dataset/train_mask/water\1742-water.png
# dataset/train_mask/water\1744-water.png
# dataset/train_mask/water\1745-water.png
# dataset/train_mask/water\1746-water.png
# dataset/train_mask/water\1747-water.png
# dataset/train_mask/water\175-water.png
# dataset/train_mask/water\1750-water.png
# dataset/train_mask/water\1751-water.png
# dataset/train_mask/water\1752-water.png
# dataset/train_mask/water\1753-water.png
# dataset/train_mask/water\1754-water.png
# dataset/train_mask/water\1755-water.png
# dataset/train_mask/water\1756-water.png
# dataset/train_mask/water\1757-water.png
# dataset/train_mask/water\1758-water.png
# dataset/train_mask/water\1759-water.png
# dataset/train_mask/water\176-water.png
# dataset/train_mask/water\1760-water.png
# dataset/train_mask/water\1761-water.png
# dataset/train_mask/water\1763-water.png
# dataset/train_mask/water\1764-water.png
# dataset/train_mask/water\1765-water.png
# dataset/train_mask/water\1766-water.png
# dataset/train_mask/water\1767-water.png
# dataset/train_mask/water\1768-water.png
# dataset/train_mask/water\1769-water.png
# dataset/train_mask/water\177-water.png
# dataset/train_mask/water\1771-water.png
# dataset/train_mask/water\1772-water.png
# dataset/train_mask/water\1773-water.png
# dataset/train_mask/water\1776-water.png
# dataset/train_mask/water\1777-water.png
# dataset/train_mask/water\1778-water.png
# dataset/train_mask/water\1779-water.png
# dataset/train_mask/water\178-water.png
# dataset/train_mask/water\1780-water.png
# dataset/train_mask/water\1781-water.png
# dataset/train_mask/water\1782-water.png
# dataset/train_mask/water\1783-water.png
# dataset/train_mask/water\1786-water.png
# dataset/train_mask/water\1788-water.png
# dataset/train_mask/water\1789-water.png
# dataset/train_mask/water\179-water.png
# dataset/train_mask/water\1791-water.png
# dataset/train_mask/water\1792-water.png
# dataset/train_mask/water\1793-water.png
# dataset/train_mask/water\1794-water.png
# dataset/train_mask/water\1795-water.png
# dataset/train_mask/water\1796-water.png
# dataset/train_mask/water\1798-water.png
# dataset/train_mask/water\1799-water.png
# dataset/train_mask/water\18-water.png
# dataset/train_mask/water\180-water.png
# dataset/train_mask/water\1802-water.png
# dataset/train_mask/water\1803-water.png
# dataset/train_mask/water\1804-water.png
# dataset/train_mask/water\1805-water.png
# dataset/train_mask/water\1807-water.png
# dataset/train_mask/water\1808-water.png
# dataset/train_mask/water\1809-water.png
# dataset/train_mask/water\181-water.png
# dataset/train_mask/water\1810-water.png
# dataset/train_mask/water\1811-water.png
# dataset/train_mask/water\1813-water.png
# dataset/train_mask/water\1815-water.png
# dataset/train_mask/water\1817-water.png
# dataset/train_mask/water\1818-water.png
# dataset/train_mask/water\1819-water.png
# dataset/train_mask/water\182-water.png
# dataset/train_mask/water\1820-water.png
# dataset/train_mask/water\1821-water.png
# dataset/train_mask/water\1822-water.png
# dataset/train_mask/water\1823-water.png
# dataset/train_mask/water\1824-water.png
# dataset/train_mask/water\1825-water.png
# dataset/train_mask/water\1826-water.png
# dataset/train_mask/water\1827-water.png
# dataset/train_mask/water\1829-water.png
# dataset/train_mask/water\1830-water.png
# dataset/train_mask/water\1831-water.png
# dataset/train_mask/water\1832-water.png
# dataset/train_mask/water\1836-water.png
# dataset/train_mask/water\1837-water.png
# dataset/train_mask/water\1838-water.png
# dataset/train_mask/water\184-water.png
# dataset/train_mask/water\1840-water.png
# dataset/train_mask/water\1841-water.png
# dataset/train_mask/water\1842-water.png
# dataset/train_mask/water\1843-water.png
# dataset/train_mask/water\1844-water.png
# dataset/train_mask/water\1845-water.png
# dataset/train_mask/water\1846-water.png
# dataset/train_mask/water\1849-water.png
# dataset/train_mask/water\1850-water.png
# dataset/train_mask/water\1851-water.png
# dataset/train_mask/water\1852-water.png
# dataset/train_mask/water\1853-water.png
# dataset/train_mask/water\1854-water.png
# dataset/train_mask/water\1855-water.png
# dataset/train_mask/water\1856-water.png
# dataset/train_mask/water\1858-water.png
# dataset/train_mask/water\1859-water.png
# dataset/train_mask/water\1860-water.png
# dataset/train_mask/water\1861-water.png
# dataset/train_mask/water\1862-water.png
# dataset/train_mask/water\1864-water.png
# dataset/train_mask/water\1866-water.png
# dataset/train_mask/water\1867-water.png
# dataset/train_mask/water\1868-water.png
# dataset/train_mask/water\1869-water.png
# dataset/train_mask/water\187-water.png
# dataset/train_mask/water\1870-water.png
# dataset/train_mask/water\1871-water.png
# dataset/train_mask/water\1872-water.png
# dataset/train_mask/water\1873-water.png
# dataset/train_mask/water\1874-water.png
# dataset/train_mask/water\1875-water.png
# dataset/train_mask/water\1876-water.png
# dataset/train_mask/water\1879-water.png
# dataset/train_mask/water\188-water.png
# dataset/train_mask/water\1880-water.png
# dataset/train_mask/water\1881-water.png
# dataset/train_mask/water\1883-water.png
# dataset/train_mask/water\1884-water.png
# dataset/train_mask/water\1885-water.png
# dataset/train_mask/water\1886-water.png
# dataset/train_mask/water\1887-water.png
# dataset/train_mask/water\1888-water.png
# dataset/train_mask/water\1889-water.png
# dataset/train_mask/water\189-water.png
# dataset/train_mask/water\1890-water.png
# dataset/train_mask/water\1891-water.png
# dataset/train_mask/water\1893-water.png
# dataset/train_mask/water\1894-water.png
# dataset/train_mask/water\1895-water.png
# dataset/train_mask/water\1896-water.png
# dataset/train_mask/water\1897-water.png
# dataset/train_mask/water\1898-water.png
# dataset/train_mask/water\1899-water.png
# dataset/train_mask/water\19-water.png
# dataset/train_mask/water\1900-water.png
# dataset/train_mask/water\1902-water.png
# dataset/train_mask/water\1903-water.png
# dataset/train_mask/water\1904-water.png
# dataset/train_mask/water\1905-water.png
# dataset/train_mask/water\1906-water.png
# dataset/train_mask/water\1907-water.png
# dataset/train_mask/water\191-water.png
# dataset/train_mask/water\1910-water.png
# dataset/train_mask/water\1911-water.png
# dataset/train_mask/water\1912-water.png
# dataset/train_mask/water\1914-water.png
# dataset/train_mask/water\1916-water.png
# dataset/train_mask/water\1917-water.png
# dataset/train_mask/water\1919-water.png
# dataset/train_mask/water\192-water.png
# dataset/train_mask/water\1920-water.png
# dataset/train_mask/water\1921-water.png
# dataset/train_mask/water\1922-water.png
# dataset/train_mask/water\1923-water.png
# dataset/train_mask/water\1924-water.png
# dataset/train_mask/water\1927-water.png
# dataset/train_mask/water\1928-water.png
# dataset/train_mask/water\1929-water.png
# dataset/train_mask/water\193-water.png
# dataset/train_mask/water\1930-water.png
# dataset/train_mask/water\1931-water.png
# dataset/train_mask/water\1932-water.png
# dataset/train_mask/water\1934-water.png
# dataset/train_mask/water\1935-water.png
# dataset/train_mask/water\1936-water.png
# dataset/train_mask/water\1937-water.png
# dataset/train_mask/water\1938-water.png
# dataset/train_mask/water\1939-water.png
# dataset/train_mask/water\194-water.png
# dataset/train_mask/water\1940-water.png
# dataset/train_mask/water\1941-water.png
# dataset/train_mask/water\1942-water.png
# dataset/train_mask/water\1943-water.png
# dataset/train_mask/water\1944-water.png
# dataset/train_mask/water\1946-water.png
# dataset/train_mask/water\1947-water.png
# dataset/train_mask/water\1949-water.png
# dataset/train_mask/water\1950-water.png
# dataset/train_mask/water\1951-water.png
# dataset/train_mask/water\1952-water.png
# dataset/train_mask/water\1953-water.png
# dataset/train_mask/water\1954-water.png
# dataset/train_mask/water\1955-water.png
# dataset/train_mask/water\1957-water.png
# dataset/train_mask/water\1959-water.png
# dataset/train_mask/water\196-water.png
# dataset/train_mask/water\1961-water.png
# dataset/train_mask/water\1962-water.png
# dataset/train_mask/water\1964-water.png
# dataset/train_mask/water\1966-water.png
# dataset/train_mask/water\1967-water.png
# dataset/train_mask/water\1968-water.png
# dataset/train_mask/water\1970-water.png
# dataset/train_mask/water\1971-water.png
# dataset/train_mask/water\1972-water.png
# dataset/train_mask/water\1973-water.png
# dataset/train_mask/water\1975-water.png
# dataset/train_mask/water\1976-water.png
# dataset/train_mask/water\1977-water.png
# dataset/train_mask/water\1978-water.png
# dataset/train_mask/water\1979-water.png
# dataset/train_mask/water\198-water.png
# dataset/train_mask/water\1981-water.png
# dataset/train_mask/water\1982-water.png
# dataset/train_mask/water\1983-water.png
# dataset/train_mask/water\1984-water.png
# dataset/train_mask/water\1986-water.png
# dataset/train_mask/water\1987-water.png
# dataset/train_mask/water\1988-water.png
# dataset/train_mask/water\1989-water.png
# dataset/train_mask/water\199-water.png
# dataset/train_mask/water\1990-water.png
# dataset/train_mask/water\1991-water.png
# dataset/train_mask/water\1994-water.png
# dataset/train_mask/water\1995-water.png
# dataset/train_mask/water\1996-water.png
# dataset/train_mask/water\1997-water.png
# dataset/train_mask/water\1999-water.png
# dataset/train_mask/water\2-water.png
# dataset/train_mask/water\20-water.png
# dataset/train_mask/water\200-water.png
# dataset/train_mask/water\2001-water.png
# dataset/train_mask/water\2002-water.png
# dataset/train_mask/water\2003-water.png
# dataset/train_mask/water\2004-water.png
# dataset/train_mask/water\2006-water.png
# dataset/train_mask/water\2008-water.png
# dataset/train_mask/water\2009-water.png
# dataset/train_mask/water\201-water.png
# dataset/train_mask/water\2010-water.png
# dataset/train_mask/water\2012-water.png
# dataset/train_mask/water\2014-water.png
# dataset/train_mask/water\2015-water.png
# dataset/train_mask/water\2016-water.png
# dataset/train_mask/water\2017-water.png
# dataset/train_mask/water\2018-water.png
# dataset/train_mask/water\2019-water.png
# dataset/train_mask/water\202-water.png
# dataset/train_mask/water\2020-water.png
# dataset/train_mask/water\2021-water.png
# dataset/train_mask/water\2023-water.png
# dataset/train_mask/water\2024-water.png
# dataset/train_mask/water\2025-water.png
# dataset/train_mask/water\2026-water.png
# dataset/train_mask/water\2028-water.png
# dataset/train_mask/water\2029-water.png
# dataset/train_mask/water\2030-water.png
# dataset/train_mask/water\2031-water.png
# dataset/train_mask/water\2032-water.png
# dataset/train_mask/water\2033-water.png
# dataset/train_mask/water\2034-water.png
# dataset/train_mask/water\2035-water.png
# dataset/train_mask/water\2036-water.png
# dataset/train_mask/water\2037-water.png
# dataset/train_mask/water\2038-water.png
# dataset/train_mask/water\204-water.png
# dataset/train_mask/water\2040-water.png
# dataset/train_mask/water\2041-water.png
# dataset/train_mask/water\2042-water.png
# dataset/train_mask/water\2043-water.png
# dataset/train_mask/water\2044-water.png
# dataset/train_mask/water\2045-water.png
# dataset/train_mask/water\2046-water.png
# dataset/train_mask/water\2048-water.png
# dataset/train_mask/water\2049-water.png
# dataset/train_mask/water\2051-water.png
# dataset/train_mask/water\2052-water.png
# dataset/train_mask/water\2053-water.png
# dataset/train_mask/water\2054-water.png
# dataset/train_mask/water\2055-water.png
# dataset/train_mask/water\2056-water.png
# dataset/train_mask/water\2057-water.png
# dataset/train_mask/water\2058-water.png
# dataset/train_mask/water\2059-water.png
# dataset/train_mask/water\206-water.png
# dataset/train_mask/water\2060-water.png
# dataset/train_mask/water\2061-water.png
# dataset/train_mask/water\2062-water.png
# dataset/train_mask/water\2063-water.png
# dataset/train_mask/water\2065-water.png
# dataset/train_mask/water\2066-water.png
# dataset/train_mask/water\2067-water.png
# dataset/train_mask/water\2068-water.png
# ...
# dataset/train_mask/water\262-water.png
# dataset/train_mask/water\263-water.png
# dataset/train_mask/water\264-water.png
# dataset/train_mask/water\265-water.png
# dataset/train_mask/water\267-water.png
# dataset/train_mask/water\268-water.png
# dataset/train_mask/water\269-water.png
# dataset/train_mask/water\270-water.png
# dataset/train_mask/water\271-water.png
# dataset/train_mask/water\272-water.png
# dataset/train_mask/water\273-water.png
# dataset/train_mask/water\275-water.png
# dataset/train_mask/water\276-water.png
# dataset/train_mask/water\277-water.png
# dataset/train_mask/water\280-water.png
# dataset/train_mask/water\281-water.png
# dataset/train_mask/water\282-water.png
# dataset/train_mask/water\283-water.png
# dataset/train_mask/water\284-water.png
# dataset/train_mask/water\285-water.png
# dataset/train_mask/water\288-water.png
# dataset/train_mask/water\29-water.png
# dataset/train_mask/water\290-water.png
# dataset/train_mask/water\293-water.png
# dataset/train_mask/water\294-water.png
# dataset/train_mask/water\295-water.png
# dataset/train_mask/water\296-water.png
# dataset/train_mask/water\297-water.png
# dataset/train_mask/water\298-water.png
# dataset/train_mask/water\299-water.png
# dataset/train_mask/water\3-water.png
# dataset/train_mask/water\30-water.png
# dataset/train_mask/water\300-water.png
# dataset/train_mask/water\301-water.png
# dataset/train_mask/water\303-water.png
# dataset/train_mask/water\304-water.png
# dataset/train_mask/water\307-water.png
# dataset/train_mask/water\308-water.png
# dataset/train_mask/water\309-water.png
# dataset/train_mask/water\31-water.png
# dataset/train_mask/water\311-water.png
# dataset/train_mask/water\312-water.png
# dataset/train_mask/water\314-water.png
# dataset/train_mask/water\315-water.png
# dataset/train_mask/water\317-water.png
# dataset/train_mask/water\318-water.png
# dataset/train_mask/water\319-water.png
# dataset/train_mask/water\32-water.png
# dataset/train_mask/water\320-water.png
# dataset/train_mask/water\321-water.png
# dataset/train_mask/water\322-water.png
# dataset/train_mask/water\323-water.png
# dataset/train_mask/water\324-water.png
# dataset/train_mask/water\326-water.png
# dataset/train_mask/water\327-water.png
# dataset/train_mask/water\329-water.png
# dataset/train_mask/water\33-water.png
# dataset/train_mask/water\330-water.png
# dataset/train_mask/water\331-water.png
# dataset/train_mask/water\334-water.png
# dataset/train_mask/water\335-water.png
# dataset/train_mask/water\336-water.png
# dataset/train_mask/water\337-water.png
# dataset/train_mask/water\339-water.png
# dataset/train_mask/water\34-water.png
# dataset/train_mask/water\340-water.png
# dataset/train_mask/water\341-water.png
# dataset/train_mask/water\344-water.png
# dataset/train_mask/water\345-water.png
# dataset/train_mask/water\346-water.png
# dataset/train_mask/water\347-water.png
# dataset/train_mask/water\348-water.png
# dataset/train_mask/water\349-water.png
# dataset/train_mask/water\35-water.png
# dataset/train_mask/water\350-water.png
# dataset/train_mask/water\351-water.png
# dataset/train_mask/water\352-water.png
# dataset/train_mask/water\353-water.png
# dataset/train_mask/water\354-water.png
# dataset/train_mask/water\355-water.png
# dataset/train_mask/water\357-water.png
# dataset/train_mask/water\358-water.png
# dataset/train_mask/water\359-water.png
# dataset/train_mask/water\36-water.png
# dataset/train_mask/water\360-water.png
# dataset/train_mask/water\361-water.png
# dataset/train_mask/water\362-water.png
# dataset/train_mask/water\363-water.png
# dataset/train_mask/water\364-water.png
# dataset/train_mask/water\365-water.png
# dataset/train_mask/water\366-water.png
# dataset/train_mask/water\369-water.png
# dataset/train_mask/water\370-water.png
# dataset/train_mask/water\371-water.png
# dataset/train_mask/water\372-water.png
# dataset/train_mask/water\373-water.png
# dataset/train_mask/water\374-water.png
# dataset/train_mask/water\375-water.png
# dataset/train_mask/water\376-water.png
# dataset/train_mask/water\377-water.png
# dataset/train_mask/water\378-water.png
# dataset/train_mask/water\38-water.png
# dataset/train_mask/water\380-water.png
# dataset/train_mask/water\381-water.png
# dataset/train_mask/water\382-water.png
# dataset/train_mask/water\383-water.png
# dataset/train_mask/water\384-water.png
# dataset/train_mask/water\385-water.png
# dataset/train_mask/water\386-water.png
# dataset/train_mask/water\387-water.png
# dataset/train_mask/water\388-water.png
# dataset/train_mask/water\389-water.png
# dataset/train_mask/water\39-water.png
# dataset/train_mask/water\390-water.png
# dataset/train_mask/water\391-water.png
# dataset/train_mask/water\392-water.png
# dataset/train_mask/water\393-water.png
# dataset/train_mask/water\394-water.png
# dataset/train_mask/water\395-water.png
# dataset/train_mask/water\396-water.png
# dataset/train_mask/water\397-water.png
# dataset/train_mask/water\398-water.png
# dataset/train_mask/water\4-water.png
# dataset/train_mask/water\40-water.png
# dataset/train_mask/water\400-water.png
# dataset/train_mask/water\402-water.png
# dataset/train_mask/water\403-water.png
# dataset/train_mask/water\404-water.png
# dataset/train_mask/water\405-water.png
# dataset/train_mask/water\407-water.png
# dataset/train_mask/water\408-water.png
# dataset/train_mask/water\409-water.png
# dataset/train_mask/water\410-water.png
# dataset/train_mask/water\411-water.png
# dataset/train_mask/water\413-water.png
# dataset/train_mask/water\415-water.png
# dataset/train_mask/water\416-water.png
# dataset/train_mask/water\417-water.png
# dataset/train_mask/water\418-water.png
# dataset/train_mask/water\419-water.png
# dataset/train_mask/water\420-water.png
# dataset/train_mask/water\421-water.png
# dataset/train_mask/water\422-water.png
# dataset/train_mask/water\423-water.png
# dataset/train_mask/water\424-water.png
# dataset/train_mask/water\425-water.png
# dataset/train_mask/water\426-water.png
# dataset/train_mask/water\427-water.png
# dataset/train_mask/water\43-water.png
# dataset/train_mask/water\430-water.png
# dataset/train_mask/water\431-water.png
# dataset/train_mask/water\433-water.png
# dataset/train_mask/water\434-water.png
# dataset/train_mask/water\435-water.png
# dataset/train_mask/water\436-water.png
# dataset/train_mask/water\437-water.png
# dataset/train_mask/water\438-water.png
# dataset/train_mask/water\439-water.png
# dataset/train_mask/water\44-water.png
# dataset/train_mask/water\441-water.png
# dataset/train_mask/water\442-water.png
# dataset/train_mask/water\443-water.png
# dataset/train_mask/water\444-water.png
# dataset/train_mask/water\445-water.png
# dataset/train_mask/water\446-water.png
# dataset/train_mask/water\447-water.png
# dataset/train_mask/water\448-water.png
# dataset/train_mask/water\449-water.png
# dataset/train_mask/water\45-water.png
# dataset/train_mask/water\452-water.png
# dataset/train_mask/water\453-water.png
# dataset/train_mask/water\454-water.png
# dataset/train_mask/water\455-water.png
# dataset/train_mask/water\456-water.png
# dataset/train_mask/water\457-water.png
# dataset/train_mask/water\458-water.png
# dataset/train_mask/water\46-water.png
# dataset/train_mask/water\460-water.png
# dataset/train_mask/water\461-water.png
# dataset/train_mask/water\463-water.png
# dataset/train_mask/water\464-water.png
# dataset/train_mask/water\466-water.png
# dataset/train_mask/water\467-water.png
# dataset/train_mask/water\469-water.png
# dataset/train_mask/water\47-water.png
# dataset/train_mask/water\470-water.png
# dataset/train_mask/water\472-water.png
# dataset/train_mask/water\473-water.png
# dataset/train_mask/water\474-water.png
# dataset/train_mask/water\475-water.png
# dataset/train_mask/water\477-water.png
# dataset/train_mask/water\478-water.png
# dataset/train_mask/water\479-water.png
# dataset/train_mask/water\48-water.png
# dataset/train_mask/water\480-water.png
# dataset/train_mask/water\481-water.png
# dataset/train_mask/water\482-water.png
# dataset/train_mask/water\483-water.png
# dataset/train_mask/water\484-water.png
# dataset/train_mask/water\485-water.png
# dataset/train_mask/water\486-water.png
# dataset/train_mask/water\488-water.png
# dataset/train_mask/water\489-water.png
# dataset/train_mask/water\49-water.png
# dataset/train_mask/water\490-water.png
# dataset/train_mask/water\491-water.png
# dataset/train_mask/water\492-water.png
# dataset/train_mask/water\493-water.png
# dataset/train_mask/water\494-water.png
# dataset/train_mask/water\495-water.png
# dataset/train_mask/water\497-water.png
# dataset/train_mask/water\498-water.png
# dataset/train_mask/water\499-water.png
# dataset/train_mask/water\50-water.png
# dataset/train_mask/water\500-water.png
# dataset/train_mask/water\502-water.png
# dataset/train_mask/water\503-water.png
# dataset/train_mask/water\504-water.png
# dataset/train_mask/water\505-water.png
# dataset/train_mask/water\506-water.png
# dataset/train_mask/water\507-water.png
# dataset/train_mask/water\508-water.png
# dataset/train_mask/water\509-water.png
# dataset/train_mask/water\510-water.png
# dataset/train_mask/water\511-water.png
# dataset/train_mask/water\512-water.png
# dataset/train_mask/water\515-water.png
# dataset/train_mask/water\516-water.png
# dataset/train_mask/water\517-water.png
# dataset/train_mask/water\518-water.png
# dataset/train_mask/water\519-water.png
# dataset/train_mask/water\520-water.png
# dataset/train_mask/water\521-water.png
# dataset/train_mask/water\522-water.png
# dataset/train_mask/water\523-water.png
# dataset/train_mask/water\524-water.png
# dataset/train_mask/water\525-water.png
# dataset/train_mask/water\526-water.png
# dataset/train_mask/water\528-water.png
# dataset/train_mask/water\53-water.png
# dataset/train_mask/water\531-water.png
# dataset/train_mask/water\532-water.png
# dataset/train_mask/water\533-water.png
# dataset/train_mask/water\534-water.png
# dataset/train_mask/water\536-water.png
# dataset/train_mask/water\537-water.png
# dataset/train_mask/water\538-water.png
# dataset/train_mask/water\539-water.png
# dataset/train_mask/water\54-water.png
# dataset/train_mask/water\540-water.png
# dataset/train_mask/water\541-water.png
# dataset/train_mask/water\542-water.png
# dataset/train_mask/water\543-water.png
# dataset/train_mask/water\544-water.png
# dataset/train_mask/water\546-water.png
# dataset/train_mask/water\547-water.png
# dataset/train_mask/water\548-water.png
# dataset/train_mask/water\549-water.png
# dataset/train_mask/water\550-water.png
# dataset/train_mask/water\551-water.png
# dataset/train_mask/water\552-water.png
# dataset/train_mask/water\554-water.png
# dataset/train_mask/water\555-water.png
# dataset/train_mask/water\556-water.png
# dataset/train_mask/water\557-water.png
# dataset/train_mask/water\559-water.png
# dataset/train_mask/water\560-water.png
# dataset/train_mask/water\561-water.png
# dataset/train_mask/water\562-water.png
# dataset/train_mask/water\563-water.png
# dataset/train_mask/water\564-water.png
# dataset/train_mask/water\565-water.png
# dataset/train_mask/water\566-water.png
# dataset/train_mask/water\567-water.png
# dataset/train_mask/water\568-water.png
# dataset/train_mask/water\57-water.png
# dataset/train_mask/water\570-water.png
# dataset/train_mask/water\571-water.png
# dataset/train_mask/water\572-water.png
# dataset/train_mask/water\573-water.png
# dataset/train_mask/water\575-water.png
# dataset/train_mask/water\576-water.png
# dataset/train_mask/water\577-water.png
# dataset/train_mask/water\578-water.png
# dataset/train_mask/water\58-water.png
# dataset/train_mask/water\580-water.png
# dataset/train_mask/water\581-water.png
# dataset/train_mask/water\582-water.png
# dataset/train_mask/water\584-water.png
# dataset/train_mask/water\585-water.png
# dataset/train_mask/water\586-water.png
# dataset/train_mask/water\588-water.png
# dataset/train_mask/water\589-water.png
# dataset/train_mask/water\590-water.png
# dataset/train_mask/water\591-water.png
# dataset/train_mask/water\592-water.png
# dataset/train_mask/water\594-water.png
# dataset/train_mask/water\595-water.png
# dataset/train_mask/water\597-water.png
# dataset/train_mask/water\598-water.png
# dataset/train_mask/water\60-water.png
# dataset/train_mask/water\600-water.png
# dataset/train_mask/water\601-water.png
# dataset/train_mask/water\602-water.png
# dataset/train_mask/water\603-water.png
# dataset/train_mask/water\604-water.png
# dataset/train_mask/water\605-water.png
# dataset/train_mask/water\607-water.png
# dataset/train_mask/water\608-water.png
# dataset/train_mask/water\609-water.png
# dataset/train_mask/water\61-water.png
# dataset/train_mask/water\610-water.png
# dataset/train_mask/water\611-water.png
# dataset/train_mask/water\612-water.png
# dataset/train_mask/water\613-water.png
# dataset/train_mask/water\614-water.png
# dataset/train_mask/water\616-water.png
# dataset/train_mask/water\617-water.png
# dataset/train_mask/water\618-water.png
# dataset/train_mask/water\619-water.png
# dataset/train_mask/water\62-water.png
# dataset/train_mask/water\620-water.png
# dataset/train_mask/water\621-water.png
# dataset/train_mask/water\623-water.png
# dataset/train_mask/water\624-water.png
# dataset/train_mask/water\625-water.png
# dataset/train_mask/water\626-water.png
# dataset/train_mask/water\627-water.png
# dataset/train_mask/water\628-water.png
# dataset/train_mask/water\629-water.png
# dataset/train_mask/water\63-water.png
# dataset/train_mask/water\630-water.png
# dataset/train_mask/water\631-water.png
# dataset/train_mask/water\634-water.png
# dataset/train_mask/water\636-water.png
# dataset/train_mask/water\638-water.png
# dataset/train_mask/water\639-water.png
# dataset/train_mask/water\64-water.png
# dataset/train_mask/water\640-water.png
# dataset/train_mask/water\641-water.png
# dataset/train_mask/water\642-water.png
# dataset/train_mask/water\643-water.png
# dataset/train_mask/water\644-water.png
# dataset/train_mask/water\645-water.png
# dataset/train_mask/water\647-water.png
# dataset/train_mask/water\648-water.png
# dataset/train_mask/water\649-water.png
# dataset/train_mask/water\65-water.png
# dataset/train_mask/water\650-water.png
# dataset/train_mask/water\651-water.png
# dataset/train_mask/water\653-water.png
# dataset/train_mask/water\654-water.png
# dataset/train_mask/water\655-water.png
# dataset/train_mask/water\656-water.png
# dataset/train_mask/water\657-water.png
# dataset/train_mask/water\658-water.png
# dataset/train_mask/water\659-water.png
# dataset/train_mask/water\66-water.png
# dataset/train_mask/water\660-water.png
# dataset/train_mask/water\661-water.png
# dataset/train_mask/water\664-water.png
# dataset/train_mask/water\665-water.png
# dataset/train_mask/water\666-water.png
# dataset/train_mask/water\667-water.png
# dataset/train_mask/water\668-water.png
# dataset/train_mask/water\67-water.png
# dataset/train_mask/water\671-water.png
# dataset/train_mask/water\672-water.png
# dataset/train_mask/water\673-water.png
# dataset/train_mask/water\674-water.png
# dataset/train_mask/water\675-water.png
# dataset/train_mask/water\676-water.png
# dataset/train_mask/water\677-water.png
# dataset/train_mask/water\678-water.png
# dataset/train_mask/water\68-water.png
# dataset/train_mask/water\680-water.png
# dataset/train_mask/water\681-water.png
# dataset/train_mask/water\682-water.png
# dataset/train_mask/water\683-water.png
# dataset/train_mask/water\684-water.png
# dataset/train_mask/water\685-water.png
# dataset/train_mask/water\686-water.png
# dataset/train_mask/water\687-water.png
# dataset/train_mask/water\688-water.png
# dataset/train_mask/water\689-water.png
# dataset/train_mask/water\69-water.png
# dataset/train_mask/water\690-water.png
# dataset/train_mask/water\691-water.png
# dataset/train_mask/water\692-water.png
# dataset/train_mask/water\693-water.png
# dataset/train_mask/water\694-water.png
# dataset/train_mask/water\696-water.png
# dataset/train_mask/water\698-water.png
# dataset/train_mask/water\699-water.png
# dataset/train_mask/water\7-water.png
# dataset/train_mask/water\701-water.png
# dataset/train_mask/water\702-water.png
# dataset/train_mask/water\703-water.png
# dataset/train_mask/water\704-water.png
# dataset/train_mask/water\705-water.png
# dataset/train_mask/water\706-water.png
# dataset/train_mask/water\707-water.png
# dataset/train_mask/water\708-water.png
# dataset/train_mask/water\709-water.png
# dataset/train_mask/water\71-water.png
# dataset/train_mask/water\710-water.png
# dataset/train_mask/water\713-water.png
# dataset/train_mask/water\714-water.png
# dataset/train_mask/water\715-water.png
# Created 6274 annotations for images in folder: dataset/train_mask/
